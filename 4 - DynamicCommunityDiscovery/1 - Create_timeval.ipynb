# %%
import pandas as pd

# %%
path = "../DataSet StackOverflow/questions_2020_2021.csv"

# %%
df = pd.read_csv(path)

# %%
df = df.sort_values(by=['Creation_date'])

# %%
df
# Out:
#                                                     Tags      User_Name  \
# 17571                              string|-|algorithm|-|            Bob
# 7013               flutter|-|paypal|-|payment-gateway|-|         Kalyan
# 45534  java|-|json|-|spring-boot|-|jackson|-|serializ...        student
# 45535                                            rust|-|         wyer33
# 45536          react-native|-|linker|-|expo|-|gallery|-|      LuckyLuke
# ...                                                  ...            ...
# 5564                                                c|-|         woowoo
# 45530                                               c|-|      Mike Chen
# 45531            database|-|tensorflow|-|output|-|tfx|-|   Sarah Messer
# 45532                                 python|-|pytest|-|  Isaiah Shiner
# 45533  javascript|-|vue.js|-|vue-component|-|vue-rout...          Mardo
#
#                                                    Title  View_count  \
# 17571  How to determine the smallest common divisor o...        3650
# 7013          Integrating Paypal payments in Flutter app       11452
# 45534     @JsonFormat not working with custom serializer         851
# 45535  How to use a trait object that contains a meth...         411
# 45536  How to open downloaded photo using gallery app...        2138
# ...                                                  ...         ...
# 5564   what does register const char *const *name; me...         231
# 45530  Using while(str[n++]!=&#39;\0&#39;) for counti...         173
# 45531  How do I get a dataframe or database write fro...         249
# 45532  Pytest: customize short test summary info, rem...         582
# 45533      Access parent component scope in b-table slot         103
#
#        Down_vote_count  Up_vote_count  Answer_count  Score  Creation_date  \
# 17571                0              5             2      5     1577837184
# 7013                 0              8             2      8     1577837378
# 45534                0              3             1      3     1577837680
# 45535                0              3             1      3     1577838195
# 45536                0              3             1      3     1577838649
# ...                ...            ...           ...    ...            ...
# 5564                 0             10             2     10     1609449801
# 45530                1              5             3      4     1609450664
# 45531                0              4             2      4     1609453137
# 45532                0              4             1      4     1609455744
# 45533                0              4             1      4     1609456124
#
#        Question_id
# 17571     59549234
# 7013      59549242
# 45534     59549259
# 45535     59549281
# 45536     59549303
# ...            ...
# 5564      65525644
# 45530     65525738
# 45531     65525944
# 45532     65526149
# 45533     65526173
#
# [50000 rows x 10 columns]

# %%
tags = []
time_tags = []

# %%
couple_tags = []
time_couple = []

# %%
for i in df.values:
    tagsss = i[0].split("|-|")[:-1]
    for t in range(len(tagsss)):
        tags.append(tagsss[t])
        time_tags.append(datetime.utcfromtimestamp(i[8]).strftime('%Y-%m-%d %H:%M:%S'))
        for j in tagsss[t+1:]:
            couple_tags.append((tagsss[t], j))  
            time_couple.append(datetime.utcfromtimestamp(i[8]).strftime('%Y-%m-%d %H:%M:%S'))

# %%
new_date = []
month = []
for i in df["Creation_date"]:
    new_date.append(datetime.utcfromtimestamp(i).strftime('%Y-%m-%d %H:%M:%S'))
    month.append(datetime.utcfromtimestamp(i).strftime('%m'))

# %%
new_df = pd.DataFrame({"Title": df["Title"], "Timeval": new_date, "Month": month})
new_df.to_csv("../DataSet StackOverflow/question_with_time.csv", index=False)

# %%
source = []
target = []
for i in couple_tags:
    source.append(i[0])
    target.append(i[1])

# %%
month = []
for i in time_tags:
    month.append(i[5:7])

# %%
new_df = pd.DataFrame({"Id": tags, "Timeval": time_tags, "Month": month})
new_df.to_csv("../DataSet StackOverflow/tags_with_time.csv", index=False)

# %%
month = []
for i in time_couple:
    month.append(i[5:7])

# %%
new_df = pd.DataFrame({"Source": source,
                       "Target": target,
                      "Timeval": time_couple, "Month": month})
new_df.to_csv("../DataSet StackOverflow/tags_edges_with_time.csv", index=False)
