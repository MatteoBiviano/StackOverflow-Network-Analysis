# %% [markdown]
# ## Renamed tags

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import networkx as nx
from operator import itemgetter

# %%
path = "../DataSet StackOverflow/edges.csv"

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')
sorted_degree = sorted(degree_dict.items(), key = itemgetter(1), reverse = True)

# %%
ids = []
count = []
named = []
original = []
for i in sorted_degree:
    ids.append(i[0])
    count.append(i[1])
    named.append("unamed")
    original.append(i[0])

# %%
def select_from_key(key, data, expection):
    al=[]
    for i in data:
        if key in i[0]:
            if len(expection)>0:
                is_except = False
                for ex in expection:
                    if ex in i[0]:
                        is_except = True
                if not is_except:
                    al.append(i[0])
            else:
                al.append(i[0])
    return al

# %%
def replace_name(old_name, new_name, old_dataset, expection):
    for i in range(len(old_dataset)):
        if old_name in old_dataset[i]:
            if len(expection)>0:
                is_except = False
                for ex in expection:
                    if ex in old_dataset[i]:
                        is_except = True
                if not is_except:
                    if "unamed" in named[i]:
                        named[i] = new_name
                        original[i] = new_name
            else:
                if "unamed" in named[i]:
                    named[i] = new_name
                    original[i] = new_name

# %%
set(original)
# Out:
# {'jax-rs',
#  'affinity',
#  'android-deep-link',
#  'pygsheets',
#  'unreachable-code',
#  'fetch-mock',
#  'autosuggest',
#  'tunnel',
#  'drc',
#  'controlvalueaccessor',
#  'method-reference',
#  'google-places-api',
#  'lua',
#  'uicontextmenuconfiguration',
#  'android-autofill-manager',
#  'git-svn',
#  'reactstrap',
#  'maven-shade-plugin',
#  'oh-my-zsh',
#  'smt',
#  'android-gradle-plugin',
#  'cloudkit',
#  'chromatic',
#  'python-logging',
#  'hls.js',
#  'relative-import',
#  'telnet',
#  'uber-api',
#  'rsync',
#  'pkcs#7',
#  'android-youtube-api',
#  'proc-sql',
#  'android-studio-3.6',
#  'git-cherry-pick',
#  'color-space',
#  'vispy',
#  'electron.net',
#  'widechar',
#  'bpmn',
#  'android-multiple-users',
#  'urlsession',
#  'android-contacts',
#  'ember.js',
#  'revenue',
#  'sum',
#  'fixpoint-combinators',
#  'npm',
#  'siri',
#  'facebook-ios-sdk-4.0',
#  'ply-file-format',
#  'uipath',
#  'theorem-proving',
#  'zef',
#  'dagre',
# ...

# %% [markdown]
# ### Replace tags  secondo il secondo principio

# %%
replace_name("android", "Android & Java Developers", ids, "")
replace_name("listview", "Android & Java Developers", ids, "")
replace_name("eclipse", "Android & Java Developers", ids, "")
replace_name("gradle", "Android & Java Developers", ids, "")
replace_name("java", "Android & Java Developers", ids, "")
replace_name("spring", "Android & Java Developers", ids, "")
replace_name("maven", "Android & Java Developers", ids, "")
replace_name("intellij", "Android & Java Developers", ids, "")
replace_name("hibernate", "Android & Java Developers", ids, "")
replace_name("jpa", "Android & Java Developers", ids, "")

# %%
replace_name("angular", "FrontEnd Developers", ids, "")
replace_name("javascript", "FrontEnd Developers", ids, "")
replace_name("typescript", "FrontEnd Developers", ids, "")
replace_name("html", "FrontEnd Developers", ids, "")
replace_name("css", "FrontEnd Developers", ids, "")
replace_name("js", "FrontEnd Developers", ids, "")
replace_name("ionic", "FrontEnd Developers", ids, "")
replace_name("observable", "FrontEnd Developers", ids, "")
replace_name("jquery", "FrontEnd Developers", ids, "")
replace_name("bootstrap", "FrontEnd Developers", ids, "")
replace_name("ecmascript", "FrontEnd Developers", ids, "")
replace_name("redux", "FrontEnd Developers", ids, "")
replace_name("express", "FrontEnd Developers", ids, "")
replace_name("ajax", "FrontEnd Developers", ids, "")
replace_name("webpack", "FrontEnd Developers", ids, "")
replace_name("php", "FrontEnd Developers", ids, "")
replace_name("laravel", "FrontEnd Developers", ids, "")
replace_name("wordpress", "FrontEnd Developers", ids, "")
replace_name("eloquent", "FrontEnd Developers", ids, "")
replace_name("ruby", "Ruby Developers", ids, "")
replace_name("activerecord", "Ruby Developers", ids, "")

# %%
replace_name("ios", "Apple Developers", ids, "")
replace_name("objective-c", "Apple Developers", ids, "")
replace_name("iphone", "Apple Developers", ids, "")
replace_name("apple", "Apple Developers", ids, "")
replace_name("xcode", "Apple Developers", ids, "")
replace_name("swift", "Apple Developers", ids, "")
replace_name("uitableview", "Apple Developers", ids, "")
replace_name("cocoa", "Apple Developers", ids, "")
replace_name("ipad", "Apple Developers", ids, "")
replace_name("macos", "Apple Developers", ids, "")
replace_name("uiview", "Apple Developers", ids, "")

# %%
replace_name("c++", "C Developers", ids, "")
replace_name("linux", "C Developers", ids, "")
replace_name("embedded", "C Developers", ids, "")
replace_name("pointers", "C Developers", ids, "")
replace_name("gcc", "C Developers", ids, "")
replace_name("arrays", "C Developers", ids, "")
replace_name("assembly", "C Developers", ids, "")
replace_name("function", "C Developers", ids, "")
replace_name("unix", "C Developers", ids, "")
replace_name("struct", "C Developers", ids, "")

# %%
for i in range(len(ids)):
    if "c" == ids[i]:
        if "unamed" in named[i]:
            named[i] = "C Developers"
            original[i] = "C Developers"

# %%
replace_name("sql", "Database Developers", ids, "")
replace_name("database", "Database Developers", ids, "")
replace_name("oracle", "Database Developers", ids, "")
replace_name("stored", "Database Developers", ids, "")
replace_name("join", "Database Developers", ids, "")
replace_name("select", "Database Developers", ids, "")
replace_name("heroku", "Database Developers", ids, "")

# %%
replace_name("python", "Python & R Developers", ids, "")
replace_name("django", "Python & R Developers", ids, "")
replace_name("pandas", "Python & R Developers", ids, "")
replace_name("numpy", "Python & R Developers", ids, "")
replace_name("list", "Python & R Developers", ids, "")
replace_name("matplotlib", "Python & R Developers", ids, "")
replace_name("tensorflow", "Python & R Developers", ids, "")
replace_name("dataframe", "Python & R Developers", ids, "")
replace_name("pip", "Python & R Developers", ids, "")
replace_name("dictionary", "Python & R Developers", ids, "")
replace_name("machine-learning", "Python & R Developers", ids, "")

#replace_name("r", "Python & R Developers", ids, "")
replace_name("plot", "Python & R Developers", ids, "")
replace_name("dplyr", "Python & R Developers", ids, "")
replace_name("data.table", "Python & R Developers", ids, "")
replace_name("shiny", "Python & R Developers", ids, "")
replace_name("regex", "Python & R Developers", ids, "")
replace_name("tidyverse", "Python & R Developers", ids, "")

# %%
for i in range(len(ids)):
    if "r" == ids[i]:
        if "unamed" in named[i]:
            named[i] = "Python & R Developers"
            original[i] = "Python & R Developers"

# %%
replace_name("git", "Version Control", ids, "")
replace_name("version-control", "Version Control", ids, "")
replace_name("branch", "Version Control", ids, "")
replace_name("ssh", "Version Control", ids, "")
replace_name("bash", "Version Control", ids, "")
replace_name("commit", "Version Control", ids, "")
replace_name("shell", "Version Control", ids, "")
replace_name("grep", "Version Control", ids, "")
replace_name("sed", "Version Control", ids, "")
replace_name("awk", "Version Control", ids, "")

# %%
saved_path2 = "../DataSet StackOverflow/nodes_tagged_by_language.csv"

new_df = pd.DataFrame({"Id": ids, "Count": count, "Named": named, "Original": original})
new_df.to_csv(saved_path2, index=False)

# %%
for i in set(new_df["Named"]):
    print(f"{i} = ", len(new_df[new_df["Named"]==i]))
# Out:
# unamed =  11375
# Database Developers =  188
# Apple Developers =  164
# Ruby Developers =  22
# Version Control =  177
# FrontEnd Developers =  699
# C Developers =  180
# Python & R Developers =  355
# Android & Java Developers =  620

# %% [markdown]
# ### INIZIO A FARE IL REPLACE DEI TAG

# %%
select_from_key("python", sorted_degree, [])
# Out:
# ['python',
#  'python-3.x',
#  'python-requests',
#  'python-3.8',
#  'python-2.7',
#  'python-asyncio',
#  'python-3.7',
#  'python-import',
#  'ipython',
#  'python-imaging-library',
#  'python-multiprocessing',
#  'python-poetry',
#  'python-3.6',
#  'cpython',
#  'python-typing',
#  'python-packaging',
#  'python-dataclasses',
#  'python-venv',
#  'plotly-python',
#  'python-multithreading',
#  'python-sphinx',
#  'python-wheel',
#  'python-unittest',
#  'python-xarray',
#  'python-internals',
#  'python-3.9',
#  'python-decorators',
#  'pythonanywhere',
#  'python-datetime',
#  'google-api-python-client',
#  'python-2.x',
#  'grpc-python',
#  'python-tesseract',
#  'python-telegram-bot',
#  'python-logging',
#  'python-cffi',
#  'python-black',
#  'mysql-python',
#  'python-module',
#  'python-behave',
#  'pythonpath',
#  'kafka-python',
#  'google-app-engine-python',
#  'python-unittest.mock',
#  'gremlinpython',
#  'opencv-python',
#  'gcloud-python',
#  'graphene-python',
# ...

# %%
replace_name("python", "Programming Languages", ids, "")

# %%
replace_name("js", "Programming Languages", ids, ["json"])

# %%
replace_name("py", "Programming Languages", ids, ["copy", "capybara", "cross-entropy", "spy"])

# %%
replace_name("java", "Programming Languages", ids, ["script"])

# %%
replace_name("c++", "Programming Languages", ids, [])

# %%
replace_name("android", "Programming Languages", ids, [])

# %%
replace_name("c#", "Programming Languages", ids, [])

# %%
replace_name("typescript", "Programming Languages", ids, [])

# %%
replace_name("swift", "Programming Languages", ids, [])

# %%
replace_name("php", "Programming Languages", ids, [])

# %%
replace_name("javascript", "Programming Languages", ids, [])

# %%
replace_name("haskell", "Programming Languages", ids, [])

# %%
replace_name("fortran", "Programming Languages", ids, [])

# %%
replace_name("ruby", "Programming Languages", ids, [])

# %%
replace_name("jenkins", "Programming Languages", ids, [])

# %%
replace_name("laravel", "Programming Languages", ids, [])

# %%
replace_name("spring", "Programming Languages", ids, [])

# %%
replace_name("rust", "Programming Languages", ids, [])

# %%
replace_name("go", "Programming Languages", ids, [])

# %%
replace_name("scala", "Programming Languages", ids, [])

# %%
replace_name("vue", "Programming Languages", ids, [])
replace_name(".net", "Programming Languages", ids, [])

# %%
replace_name("flutter", "Programming Languages", ids, [])
replace_name("angular", "Programming Languages", ids, [])
replace_name("html", "Programming Languages", ids, [])

# %%
replace_name("django", "Programming Languages", ids, [])
replace_name("css", "Programming Languages", ids, [])

# %%
replace_name("react", "Programming Languages", ids, [])
replace_name("selenium", "Programming Languages", ids, [])

# %%
replace_name("ionic", "Programming Languages", ids, [])
replace_name("bootstrap", "Programming Languages", ids, [])

# %%
replace_name("db", "DataBase", ids, [])

# %%
replace_name("sql", "DataBase", ids, [])

# %%
replace_name("jquery", "DataBase", ids, [])

# %%
replace_name("database", "DataBase", ids, [])

# %%
replace_name("api", "DataBase", ids, [])

# %%
replace_name("ios", "Operative Systems", ids, [])
replace_name("cpu", "Operative Systems", ids, [])
replace_name("audio", "Operative Systems", ids, [])
replace_name("apple", "Operative Systems", ids, [])
replace_name("video", "Operative Systems", ids, [])
replace_name("microsoft", "Operative Systems", ids, [])
replace_name("sms", "Operative Systems", ids, [])

# %%
replace_name("json", "Data structures & functions", ids, [])

# %%
replace_name("xml", "Data structures & functions", ids, [])

# %%
replace_name("peg", "Data structures & functions", ids, [])

# %%
replace_name("number", "Data structures & functions", ids, [])

# %%
replace_name("date", "Data structures & functions", ids, [])

# %%
replace_name("time", "Data structures & functions", ids, [])

# %%
replace_name("math", "Data structures & functions", ids, [])

# %%
replace_name("file", "Data structures & functions", ids, [])

# %%
replace_name("torch", "Data structures & functions", ids, [])

# %%
replace_name("learning", "Data structures & functions", ids, [])

# %%
replace_name("forest", "Data structures & functions", ids, [])

# %%
replace_name("mining", "Data structures & functions", ids, [])

# %%
replace_name("graph", "Data structures & functions", ids, [])

# %%
replace_name("sort", "Data structures & functions", ids, [])

# %%
replace_name("error", "Data structures & functions", ids, [])

# %%
replace_name("docker", "Development Tools", ids, [])

# %%
replace_name("amazon", "Development Tools", ids, [])

# %%
replace_name("aws", "Development Tools", ids, ["typeclass-laws"])

# %%
replace_name("google", "Development Tools", ids, [])

# %%
replace_name("azure", "Development Tools", ids, [])
replace_name("virtual", "Development Tools", ids, [])

# %%
replace_name("studio", "Development Tools", ids, [])

# %%
replace_name("eclipse", "Development Tools", ids, [])

# %%
replace_name("xcode", "Development Tools", ids, [])

# %%
replace_name("maven", "Development Tools", ids, [])

# %%
replace_name("sublime", "Development Tools", ids, [])

# %%
replace_name("heroku", "Development Tools", ids, [])

# %%
replace_name("git", "Development Tools", ids, ["digit", "ngit", "egit", "ogit", "bgit"])

# %%
replace_name("cloud", "Development Tools", ids, [])

# %%
replace_name("mail", "Web & Application Servers", ids, [])

# %%
replace_name("http", "Web & Application Servers", ids, [])

# %%
replace_name("client", "Web & Application Servers", ids, [])

# %%
replace_name("server", "Web & Application Servers", ids, [])

# %%
replace_name("rest", "Web & Application Servers", ids, ["forest", "restore", "restructuredtext", "restify", "prestashop", "restrict", "resto", "restri"])

# %%
replace_name("link", "Web & Application Servers", ids, [])

# %%
replace_name("mozilla", "Web & Application Servers", ids, [])
replace_name("firefox", "Web & Application Servers", ids, [])

# %%
replace_name("graphic", "Web & Application Servers", ids, [])

# %%
replace_name("facebook", "Web & Application Servers", ids, [])
replace_name("twitter", "Web & Application Servers", ids, [])
replace_name("instagram", "Web & Application Servers", ids, [])
replace_name("social", "Web & Application Servers", ids, [])

# %%
replace_name("auth", "Web & Application Servers", ids, [])
replace_name("secur", "Web & Application Servers", ids, [])
replace_name("crypto", "Web & Application Servers", ids, [])

# %%
replace_name("url", "Web & Application Servers", ids, [])

# %%
replace_name("material", "Web & Application Servers", ids, [])

# %%
replace_name("ui", "Web & Application Servers", ids, ["build", "uin", "qui", "quick", "quil", "uid", "uig"])

# %%
replace_name("frontend", "Web & Application Servers", ids, [])

# %%
replace_name("web", "Web & Application Servers", ids, [])

# %%
len(set(original))
# Out:
# 6730

# %% [markdown]
# ### Creazione csv

# %%
saved_path = "../DataSet StackOverflow/nodes_tagged.csv"

# %%
new_df = pd.DataFrame({"Id": ids, "Count": count, "Named": named, "Original": original})
new_df.to_csv(saved_path, index=False)

# %% [markdown]
# # Funzione ausiliaria

# %%
select_from_key("bit", sorted_degree, [])
# Out:
# ['bit-manipulation',
#  'bitbucket',
#  'rabbitmq',
#  '64-bit',
#  'bit-shift',
#  'bitwise-operators',
#  'bitbucket-pipelines',
#  'bitcoin',
#  'bitmap',
#  '32-bit',
#  'bit-fields',
#  'android-bitmap',
#  'bit',
#  'bitset',
#  'bitmask',
#  '32bit-64bit',
#  'bitcode',
#  'bitboard',
#  'bitnami',
#  'diskarbitration',
#  'bitpay',
#  '24-bit',
#  'bit-representation',
#  '128-bit',
#  'bit64',
#  'errbit',
#  'rabbitmq-exchange',
#  'bitmap-fonts',
#  'bit.dev']

# %%
set(ids)
# Out:
# {'dexie',
#  'uipageviewcontroller',
#  'web-component-tester',
#  'delta-lake',
#  'intersection',
#  'gnupg',
#  'propagation',
#  'whenever',
#  'pseudo-element',
#  'luajit',
#  'grafana',
#  'hive',
#  'gatt',
#  'ktlint',
#  'window',
#  'azure-service-fabric',
#  'go-git',
#  'latitude-longitude',
#  'currency',
#  'angular9',
#  'fstream',
#  'vectorization',
#  'celery-task',
#  'system.io.pipelines',
#  'rewriting',
#  'source-maps',
#  'aswebauthenticationsession',
#  'unique-id',
#  'log4net',
#  'slack',
#  'cloning',
#  'python-s3fs',
#  'ubsan',
#  'elasticsearch',
#  'continuous-integration',
#  'react-native-ble-plx',
#  'socket.io',
#  'single-page-application',
#  'fzf',
#  'react-draft-wysiwyg',
#  'font-family',
#  'tomcat',
#  'deobfuscation',
#  'mapbox-ios-maps',
#  'angular-router-events',
#  'azure-cognitive-search',
#  'keystore',
#  'postfix-operator',
#  'weak-head-normal-form',
#  'sum',
#  'argument-dependent-lookup',
#  'event-dispatch-thread',
# ...
