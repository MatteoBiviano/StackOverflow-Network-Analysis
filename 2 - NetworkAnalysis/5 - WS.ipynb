# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter
import powerlaw
from networkx.drawing.nx_agraph import graphviz_layout
import pickle
from statistics import mean, stdev
import seaborn as sns

# %%
from net_analysis import *

# %%
path = "../DataSet StackOverflow/edges.csv"

# %%
path_graph = "../DataSet StackOverflow/Graph_data/"

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 13780
# Number of edges: 97892
# Average degree:  14.2078

# %%
ws_G = nx.watts_strogatz_graph(G.number_of_nodes(), k=14, p=0.1, seed = 42)
print("Nodes:",ws_G.number_of_nodes())
print("Edges:",ws_G.number_of_edges())
# Out:
# Nodes: 13780
# Edges: 96460

# %%
nx.write_graphml(ws_G, path_graph+"WS_Network.graphml")

# %% [markdown]
# ## 1 - Degree Distribution

# %%
degree_dist(ws_G, "Watts_Strogatz", "WS")

# %%
plot_dist(ws_G, "Watts_Strogatz", "WS")
# Out:
# Calculating best minimal value for power law fit
# c:\users\matte\.conda\envs\ambiente_con_librerie\lib\site-packages\powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# C:\Users\matte\Desktop\Magistrale\Primo Anno Secondo Semestre\SNA\Progetto_SNA_Biviano_Currao_Graziani\2 - NetworkAnalysis\net_analysis.py:40: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim((min(degree), max(degree)))
# c:\users\matte\.conda\envs\ambiente_con_librerie\lib\site-packages\powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# **** Degree Distribution for Watts_Strogatz graph ****
# alpha=2.3486464583190942 sigma=0.07608089457264365

# %%
info_degree(ws_G, "Watts_Strogatz")
# Out:
# ***** Degree info for Watts_Strogatz graph ***
# Maximum degree: (20, 6189)
# Minimum degree: (9, 681)

# %% [markdown]
# ## 2 - Connected Components

# %%
components = n_connected_components(ws_G, "Watts_Strogatz")
# Out:
# **** Connected components for Watts_Strogatz graph ****
# Number of Connected Components for Watts_Strogatz: 1
# 	 component len = 13780

# %% [markdown]
# ## 3 - Path Analysis

# %%
path_analysis(ws_G, "Watts_Strogatz", components)
# Out:
# ***** Path analysis for Watts_Strogatz graph
# Diameter for components 0 network Watts_Strogatz: 8
# Average shortest path for components 0 network Watts_Strogatz: 5.3136764566006764

# %% [markdown]
# ## 4 - Clustering Coefficient

# %%
name, values = c_coefficient_analysis(ws_G, "Watts_Strogatz")
# Out:
# *** Clustering coefficient analyssi for Watts_Strogatz graph ***
# Min: 0.15384615384615385
# Max: 0.8055555555555556
# Mean: 0.5066122929127541
# Stdev: 0.09425590393080376

# %%
degree_clustering(ws_G, "Watts_Strogatz", "WS")
# Out:
# **** Distribution degree/clustering for Watts_Strogatz graph ***

# %% [markdown]
# ## 5 - Density Analysis

# %%
density_analysis(ws_G, "Watts_Strogatz")
# Out:
# Density for Watts_Strogatz graph: 0.00101603889977502
