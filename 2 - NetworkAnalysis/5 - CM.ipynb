# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter
import powerlaw
from networkx.drawing.nx_agraph import graphviz_layout
import pickle
from statistics import mean, stdev
import seaborn as sns

# %%
from net_analysis import *

# %%
path = "../DataSet StackOverflow/edges.csv"

# %%
path_graph = "../DataSet StackOverflow/Graph_data/"

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 13780
# Number of edges: 97892
# Average degree:  14.2078

# %%
# fitting the degree distribution of the RW
degrees = [d for u, d in G.degree()]  
cmodel = nx.configuration_model(degrees) 
print("Nodes:", cmodel.number_of_nodes())
print("Edges:", cmodel.number_of_edges())
# Out:
# Nodes: 13780
# Edges: 97892

# %%
nx.write_graphml(cmodel, path_graph+"CM_Network.graphml")

# %% [markdown]
# ## 1 - Degree Distribution

# %%
degree_dist(cmodel, "Configuration Model", "CM")

# %%
plot_dist(cmodel, "Configuration Model", "CM")
# Out:
# Calculating best minimal value for power law fit
# c:\users\matte\.conda\envs\ambiente_con_librerie\lib\site-packages\powerlaw.py:699: RuntimeWarning: divide by zero encountered in true_divide
#   (CDF_diff**2) /
# c:\users\matte\.conda\envs\ambiente_con_librerie\lib\site-packages\powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# C:\Users\matte\Desktop\Magistrale\Primo Anno Secondo Semestre\SNA\Progetto_SNA_Biviano_Currao_Graziani\2 - NetworkAnalysis\net_analysis.py:40: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim((min(degree), max(degree)))
# c:\users\matte\.conda\envs\ambiente_con_librerie\lib\site-packages\powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# **** Degree Distribution for Configuration Model graph ****
# alpha=2.6785326735312682 sigma=0.055218205861888504

# %%
info_degree(cmodel , "Configuration Model")
# Out:
# ***** Degree info for Configuration Model graph ***
# Maximum degree: (2784, 25)
# Minimum degree: (1, 789)

# %% [markdown]
# ## 2 - Connected Components

# %%
components = n_connected_components(cmodel , "Configuration Model")
# Out:
# **** Connected components for Configuration Model graph ****
# Number of Connected Components for Configuration Model: 2
# 	 component len = 13778
# 	 component len = 2

# %% [markdown]
# ## 3 - Path Analysis

# %%
path_analysis(cmodel , "Configuration Model", components)
# Out:
# ***** Path analysis for Configuration Model graph
# Diameter for components 0 network Configuration Model: 7
# Average shortest path for components 0 network Configuration Model: 3.148752183561156

# %% [markdown]
# ## 4 - Clustering Coefficient

# %%
# not implemented for multigraph

# %% [markdown]
# ## 5 - Density Analysis

# %%
density_analysis(cmodel , "Configuration Model")
# Out:
# Density for Configuration Model graph: 0.0010311225375987587
