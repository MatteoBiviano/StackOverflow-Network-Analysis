# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter
import powerlaw
from networkx.drawing.nx_agraph import graphviz_layout
import pickle
from statistics import mean, stdev
import seaborn as sns

# %%
from net_analysis import *

# %%
path = "../DataSet StackOverflow/edges.csv"

# %%
path_graph = "../DataSet StackOverflow/Graph_data/"

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 13780
# Number of edges: 97892
# Average degree:  14.2078

# %%
er_G = nx.erdos_renyi_graph(G.number_of_nodes(), p=0.001033 , directed = False, seed = 42)
print("Nodes:", er_G.number_of_nodes())
print("Edges:", er_G.number_of_edges())
# Out:
# Nodes: 13780
# Edges: 97895

# %%
nx.write_graphml(er_G, path_graph+"ER_Network.graphml")

# %% [markdown]
# ## 1 - Degree Distribution

# %%
degree_dist(er_G, "Erdos_Renyi", "ER")

# %%
plot_dist(er_G, "Erdos_Renyi", "ER")
# Out:
# Calculating best minimal value for power law fit
# c:\users\matte\.conda\envs\ambiente_con_librerie\lib\site-packages\powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# C:\Users\matte\Desktop\Magistrale\Primo Anno Secondo Semestre\SNA\Progetto_SNA_Biviano_Currao_Graziani\2 - NetworkAnalysis\net_analysis.py:40: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim((min(degree), max(degree)))
# c:\users\matte\.conda\envs\ambiente_con_librerie\lib\site-packages\powerlaw.py:699: RuntimeWarning: invalid value encountered in true_divide
#   (CDF_diff**2) /
# **** Degree Distribution for Erdos–Renyi graph ****
# alpha=7.079219522290286 sigma=1.9197645300406267

# %%
info_degree(er_G , "Erdos_Renyi")
# Out:
# ***** Degree info for Erdos–Renyi graph ***
# Maximum degree: (29, 5965)
# Minimum degree: (3, 358)

# %% [markdown]
# ## 2 - Connected Components

# %%
components = n_connected_components(er_G , "Erdos_Renyi")
# Out:
# **** Connected components for Erdos–Renyi graph ****
# Number of Connected Components for Erdos–Renyi: 1
# 	 component len = 13780

# %% [markdown]
# ## 3 - Path Analysis

# %%
path_analysis(er_G , "Erdos_Renyi", components)
# Out:
# ***** Path analysis for Erdos–Renyi graph
# Diameter for components 0 network Erdos–Renyi: 6
# Average shortest path for components 0 network Erdos–Renyi: 3.8615007524439022

# %% [markdown]
# ## 4 - Clustering Coefficient

# %%
name, values = c_coefficient_analysis(er_G , "Erdos_Renyi")
# Out:
# *** Clustering coefficient analyssi for Erdos_Renyi graph ***
# Min: 0
# Max: 0.06666666666666667
# Mean: 0.0010330295757325814
# Stdev: 0.003702612200147742

# %%
degree_clustering(er_G , "Erdos_Renyi", "ER")
# Out:
# **** Distribution degree/clustering for Erdos_Renyi graph ***

# %% [markdown]
# ## 5 - Density Analysis

# %%
density_analysis(er_G , "Erdos_Renyi")
# Out:
# Density for Erdos_Renyi graph: 0.0010311541373986687
